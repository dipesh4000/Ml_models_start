# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
dataset = pd.read_csv('diabetes.csv', index_col=False)

# %%
x = dataset.drop('Outcome', axis=1)
y = dataset['Outcome']

# %%
from  sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=1000)

# %%
x.shape
# Out:
# (768, 8)

# %%
i = 8
scores = [0,0,0,0,0,0,0,0]
features = [0,0,0,0,0,0,0,0]

# %%
while(i>0):
    fs = SFS(lr, k_features=i, forward=True)
    fs.fit(x,y)
    scores[i-1] = fs.k_score_
    features[i-1] = fs.k_feature_names_
    i -=1

# %%
for i in range(1, 8):
    print(f'For {features[i]} features, the accuracy is {scores[i-1]*100:.5f}')
# Out:
# For ('Glucose', 'BMI') features, the accuracy is 74.74747
# For ('Glucose', 'BMI', 'Age') features, the accuracy is 75.91206
# For ('Glucose', 'Insulin', 'BMI', 'Age') features, the accuracy is 76.83049
# For ('Pregnancies', 'Glucose', 'Insulin', 'BMI', 'Age') features, the accuracy is 76.82964
# For ('Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age') features, the accuracy is 77.08768
# For ('Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age') features, the accuracy is 77.47899
# For ('Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age') features, the accuracy is 77.47899
